# %%
# Import dependencies
from citipy import citipy
import pandas as pd
import numpy as np
import json 
import requests
import timeit

from datetime import datetime
from config import weather_api_key

# %%
# Create a new set of 2,000 random latitudes and longitudes
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Unpack lat_lngs zip object into a list. This way, we only need to create a set of random latitudes and longitudes once. 
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)
print (coordinates)
# Out:
# [(9.441506455791483, 171.04693405638176), (-82.83235714211376, -128.0731653900939), (8.576631675098497, 90.54932805304753), (2.037541787518677, 19.697058300226075), (-32.63420157140575, -133.5798317964472), (-73.92460596018574, 2.228991915908125), (-83.44756630247728, 65.55205073151774), (-63.013721975232855, 127.18778492167849), (-67.36367732977007, 21.817075183914284), (-1.7319304577402477, -86.17996740868662), (-43.85919462418513, 74.01767911061879), (-84.59467621416941, -85.61198284642767), (52.99837502919493, -105.94297707671997), (-10.235189461162989, -31.297749601151054), (-48.31243224312491, 175.6258008009235), (-47.54378698370652, -70.53899143351217), (8.562975727257324, -149.70093864242506), (-2.3064584267274597, 12.810532036100767), (-9.351882932337134, 157.69916841383082), (-20.774720034354587, 131.14420248668176), (42.08455865257977, -115.93329762749916), (-40.89307869868796, -131.2478279897066), (6.0263637878381076, 152.43461746994018), (-65.51518799541448, 108.22994147841541), (12.319658547022101, 96.77796744744768), (62.36168731732627, -21.999567593574483), (-64.37424402454207, 126.27913566209128), (-80.13481166081027, -7.12918187606752), (6.659576236622499, -132.88152665204584), (-59.031488921877255, -13.47078150450659), (-49.373329047955814, -103.65111028834876), (40.72716342270289, 8.206486526749984), (-14.873353657139262, -179.02004984360855), (-10.993339282090616, 51.34442308906142), (29.588022998460005, 132.8268890046171), (62.140267876499706, -41.923146995871065), (-82.8165781771063, 173.38849492011224), (2.8606572451905663, -103.05667963340787), (-89.05384563583426, -87.99168984539492), (34.90526746290806, -33.881797214331414), (-58.716509186281684, -104.00738406618817), (-57.73461409972984, -75.34671904680074), (-47.81835892750765, 64.87387406614619), (-54.67455793049479, -37.71553361114951), (-54.86562293767578, -151.84109767982594), (31.222553745290426, 155.05298890175493), (-29.334761786341716, -66.1786127171247), (20.921690454833012, 147.24201296426202), (-41.89072958076705, -75.8061618093598), (-9.384924530014146, 91.02221697989233), (-81.60172771321784, -154.33532200033594), (35.016114221362, -113.95727136623076), (-55.04994733537475, 128.59728195389567), (23.894154093634995, 99.0161100715265), (48.25117742463877, -57.6039698339234), (6.143738298854927, 82.4311945954828), (0.9595181589768487, -50.24823058460578), (9.838550622404, 11.738105689070892), (-39.492834896705936, -60.2653976862011), (0.3050124443705755, 148.72536489642005), (-6.855212871967723, 16.517261701274265), (49.44751578870611, -106.524046838429), (-72.80759546770679, -170.54563440263166), (-72.03400415411113, 147.75856550419763), (-45.54725691590138, 134.30168360387023), (23.18573368692725, -83.20680572720858), (8.402915722022797, 17.684267947224043), (66.91474130383756, 166.3493285747673), (-79.86951257808141, 179.67670448069953), (-79.69856965504366, 46.85768640543347), (88.72351190856108, 48.52968787554289), (-82.04050495554647, -69.51018735312579), (57.01034939873881, -53.74330710717598), (39.944502267538525, -96.48471098315974), (9.829143482235821, -175.9064134894413), (-63.09426002368861, 42.85416655064611), (-27.82973578066577, -129.96598308781407), (-79.54211384038575, 143.92347754504556), (-83.13991371613929, -111.20466875727318), (49.76138582190603, -75.85461552077751), (79.61750024594281, 173.55136362115172), (-25.031957627327373, -165.14686394968672), (-9.493974214065403, -137.8038844021991), (84.50231462233143, -165.6698318584014), (41.61026168555699, 113.2861810604104), (-56.77995901466371, 155.98660776398583), (88.72323437118703, 16.51888284809749), (-56.10341523052358, 58.77923269456275), (-10.409387974550228, -38.065968024139124), (-77.40385391821172, 122.76412703220211), (45.10151691591801, -56.45215531086397), (15.730560753546271, 8.175248633674101), (-60.55022568432007, -58.31914025681793), (-13.704847451567915, -114.41423936002711), (-39.969895083252894, -4.731993955101444), (32.30955001359176, -158.898614645 ...

# %%
# Get the nearest city using the citipy module
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 728

# %%
# Perform an API call with the OpenWeatherMap
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Retrieve the following information from the API call:
# Latitude and longitude
# Maximum temperature
# Percent humidity
# Percent cloudiness
# Wind speed
# Weather description (for example, clouds, fog, light rain, clear sky)

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        description = city_weather['weather'][0]['description']
        
        # Convert the date to ISO
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information to the city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":description })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | butaritari
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | port blair
# Processing Record 4 of Set 1 | binga
# Processing Record 5 of Set 1 | hermanus
# Processing Record 6 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 7 of Set 1 | new norfolk
# Processing Record 8 of Set 1 | bredasdorp
# Processing Record 9 of Set 1 | san cristobal
# Processing Record 10 of Set 1 | mahebourg
# Processing Record 11 of Set 1 | ushuaia
# Processing Record 12 of Set 1 | prince albert
# Processing Record 13 of Set 1 | sao jose da coroa grande
# Processing Record 14 of Set 1 | southbridge
# Processing Record 15 of Set 1 | coihaique
# Processing Record 16 of Set 1 | hilo
# Processing Record 17 of Set 1 | matsanga
# City not found. Skipping...
# Processing Record 18 of Set 1 | gizo
# Processing Record 19 of Set 1 | alice springs
# Processing Record 20 of Set 1 | mountain home
# Processing Record 21 of Set 1 | kavieng
# Processing Record 22 of Set 1 | albany
# Processing Record 23 of Set 1 | mergui
# City not found. Skipping...
# Processing Record 24 of Set 1 | grindavik
# Processing Record 25 of Set 1 | atuona
# Processing Record 26 of Set 1 | cape town
# Processing Record 27 of Set 1 | castro
# Processing Record 28 of Set 1 | alghero
# Processing Record 29 of Set 1 | halalo
# City not found. Skipping...
# Processing Record 30 of Set 1 | ambilobe
# Processing Record 31 of Set 1 | kushima
# Processing Record 32 of Set 1 | nanortalik
# Processing Record 33 of Set 1 | bluff
# Processing Record 34 of Set 1 | puerto ayora
# Processing Record 35 of Set 1 | ribeira grande
# Processing Record 36 of Set 1 | punta arenas
# Processing Record 37 of Set 1 | saint-philippe
# Processing Record 38 of Set 1 | mar del plata
# Processing Record 39 of Set 1 | mataura
# Processing Record 40 of Set 1 | hasaki
# Processing Record 41 of Set 1 | la rioja
# Processing Record 42 of Set 1 | katsuura
# Processing Record 43 of Set 1 | ancud
# Processing Record 44 of Set 1 | bengkulu
# Processing Record 45 of Set 1 | kingman
# Processing Record 46 of Set 1 | mount gambier
# Processing Record 47 of Set 1 | lashio
# Processing Record 48 of Set 1 | burgeo
# Processing Record 49 of Set 1 | wattegama
# Processing Record 50 of Set 1 | afua
# Processing Record 1 of Set 2 | numan
# Processing Record 2 of Set 2 | tres arroyos
# Processing Record 3 of Set 2 | lorengau
# Processing Record 4 of Set 2 | kasongo-lunda
# Processing Record 5 of Set 2 | gravelbourg
# Processing Record 6 of Set 2 | vaini
# Processing Record 7 of Set 2 | hobart
# Processing Record 8 of Set 2 | bahia honda
# Processing Record 9 of Set 2 | moissala
# Processing Record 10 of Set 2 | bilibino
# Processing Record 11 of Set 2 | kaitangata
# Processing Record 12 of Set 2 | port alfred
# Processing Record 13 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 14 of Set 2 | saint anthony
# Processing Record 15 of Set 2 | beatrice
# Processing Record 16 of Set 2 | kapaa
# Processing Record 17 of Set 2 | chapais
# Processing Record 18 of Set 2 | pevek
# Processing Record 19 of Set 2 | avarua
# Processing Record 20 of Set 2 | barrow
# Processing Record 21 of Set 2 | jining
# Processing Record 22 of Set 2 | tuatapere
# Processing Record 23 of Set 2 | longyearbyen
# Processing Record 24 of Set 2 | poco verde
# Processing Record 25 of Set 2 | saint-pierre
# Processing Record 26 of Set 2 | tanout
# Processing Record 27 of Set 2 | saldanha
# Processing Record 28 of Set 2 | isiro
# Processing Record 29 of Set 2 | teahupoo
# Processing Record 30 of Set 2 | saint-joseph
# Processing Record 31 of Set 2 | kodiak
# Processing Record 32 of Set 2 | ketchikan
# Processing Record 33 of Set 2 | ilulissat
# Processing Record 34 of Set 2 | clyde river
# Processing Record 35 of Set 2 | iqaluit
# Processing Record 36 of Set 2 | uwayl
# City not found. Skipping...
# Processing Record 37 of Set 2 | mayor pablo lagerenza
# Processing Record 38 of Set 2 | whitianga
# Processing Record 39 of Set 2 | dungarpur
# Processing Record 40 of Set 2 | broome
# Processing Record 41 of Set 2 | vila franca do campo
# Processing Record 42 of Set 2 | carnarvon
# Processing Record 43 of Set 2 | georgetown
# Processing Record 44 of Set 2 | sorland
# Processing Record 45 of Set 2 | jamestown
# Processing Record 46 of Set 2 | marystown
# Processing Record 47 of Set 2 | aksu
# Processing Record 48 of Set 2 | ngaoundere
# Processing Record 49 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 50 of Set 2 | tabialan
# City not found. Skipping...
# Processing Record 1 of Set 3 | porto nacional
# Processing Record 2 of Set 3 | sao geraldo do araguaia
# Processing Record 3 of Set 3 | saskylakh
# Processing Record 4 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 5 of Set 3 | khani
# Processing Record 6 of Set 3 | talnakh
# Processing Record 7 of Set 3 | yellowknife
# Processing Record 8 of Set 3 | guerrero negro
# Processing Record 9 of Set 3 | nanakuli
# Processing Record 10 of Set 3 | cam ranh
# Processing Record 11 of Set 3 | qaanaaq
# Processing Record 12 of Set 3 | kruisfontein
# Processing Record 13 of Set 3 | camacha
# Processing Record 14 of Set 3 | soyo
# Processing Record 15 of Set 3 | chokurdakh
# Processing Record 16 of Set 3 | southport
# Processing Record 17 of Set 3 | utiroa
# City not found. Skipping...
# Processing Record 18 of Set 3 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 19 of Set 3 | plettenberg bay
# Processing Record 20 of Set 3 | picayune
# Processing Record 21 of Set 3 | thinadhoo
# Processing Record 22 of Set 3 | beidao
# Processing Record 23 of Set 3 | weligama
# Processing Record 24 of Set 3 | stepnogorsk
# Processing Record 25 of Set 3 | krathum baen
# Processing Record 26 of Set 3 | hami
# Processing Record 27 of Set 3 | longlac
# City not found. Skipping...
# Processing Record 28 of Set 3 | ballina
# Processing Record 29 of Set 3 | mananara
# Processing Record 30 of Set 3 | kalemie
# Processing Record 31 of Set 3 | rongcheng
# Processing Record 32 of Set 3 | gushikawa
# Processing Record 33 of Set 3 | srednekolymsk
# Processing Record 34 of Set 3 | potoru
# Processing Record 35 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 36 of Set 3 | hue
# Processing Record 37 of Set 3 | zhanaozen
# Processing Record 38 of Set 3 | lac du bonnet
# Processing Record 39 of Set 3 | lavrentiya
# Processing Record 40 of Set 3 | busselton
# Processing Record 41 of Set 3 | ambon
# Processing Record 42 of Set 3 | deputatskiy
# Processing Record 43 of Set 3 | kununurra
# Processing Record 44 of Set 3 | novo aripuana
# Processing Record 45 of Set 3 | mulege
# Processing Record 46 of Set 3 | oranjemund
# Processing Record 47 of Set 3 | george
# Processing Record 48 of Set 3 | cidreira
# Processing Record 49 of Set 3 | port elizabeth
# Processing Record 50 of Set 3 | chisinau
# Processing Record 1 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 2 of Set 4 | caravelas
# Processing Record 3 of Set 4 | fare
# Processing Record 4 of Set 4 | inirida
# Processing Record 5 of Set 4 | manyoni
# Processing Record 6 of Set 4 | bahia blanca
# Processing Record 7 of Set 4 | nikolskoye
# Processing Record 8 of Set 4 | ginda
# Processing Record 9 of Set 4 | tuktoyaktuk
# Processing Record 10 of Set 4 | fortuna
# Processing Record 11 of Set 4 | nouadhibou
# Processing Record 12 of Set 4 | sitka
# Processing Record 13 of Set 4 | xai-xai
# Processing Record 14 of Set 4 | port augusta
# Processing Record 15 of Set 4 | lunglei
# Processing Record 16 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 17 of Set 4 | soria
# Processing Record 18 of Set 4 | kahului
# Processing Record 19 of Set 4 | vanavara
# Processing Record 20 of Set 4 | arraial do cabo
# Processing Record 21 of Set 4 | sri aman
# Processing Record 22 of Set 4 | khatanga
# Processing Record 23 of Set 4 | luderitz
# Processing Record 24 of Set 4 | ust-tsilma
# Processing Record 25 of Set 4 | egvekinot
# Processing Record 26 of Set 4 | khuzdar
# Processing Record 27 of Set 4 | urucara
# Processing Record 28 of Set 4 | majene
# Processing Record 29 of Set 4 | biograd na moru
# Processing Record 30 of Set 4 | gijon
# Processing Record 31 of Set 4 | hithadhoo
# Processing Record 32 of Set 4 | nishihara
# Processing Record 33 of Set 4 | kushiro
# Processing Record 34 of Set 4 | rawson
# Processing Record 35 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 36 of Set 4 | sharjah
# Processing Record 37 of Set 4 | ishigaki
# Processing Record 38 of Set 4 | esmeralda
# Processing Record 39 of Set 4 | teknaf
# Processing Record 40 of Set 4 | wagar
# Processing Record 41 of Set 4 | puno
# Processing Record 42 of Set 4 | tabat
# Processing Record 43 of Set 4 | road town
# Processing Record 44 of Set 4 | gladstone
# Processing Record 45 of Set 4 | port hedland
# Processing Record 46 of Set 4 | maloshuyka
# City not found. Skipping...
# Processing Record 47 of Set 4 | brodick
# Processing Record 48 of Set 4 | baracoa
# Processing Record 49 of Set 4 | geraldton
# Processing Record 50 of Set 4 | alofi
# Processing Record 1 of Set 5 | ust-nera
# Processing Record 2 of Set 5 | margate
# Processing Record 3 of Set 5 | gora
# Processing Record 4 of Set 5 | ampanihy
# Processing Record 5 of Set 5 | tommot
# Processing Record 6 of Set 5 | sawtell
# Processing Record 7 of Set 5 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 8 of Set 5 | ahipara
# Processing Record 9 of Set 5 | draguseni
# Processing Record 10 of Set 5 | salina
# Processing Record 11 of Set 5 | otane
# Processing Record 12 of Set 5 | klaksvik
# Processing Record 13 of Set 5 | mairana
# Processing Record 14 of Set 5 | beruwala
# Processing Record 15 of Set 5 | bathsheba
# Processing Record 16 of Set 5 | ponta do sol
# Processing Record 17 of Set 5 | baijiantan
# Processing Record 18 of Set 5 | novyy urengoy
# Processing Record 19 of Set 5 | narsaq
# Processing Record 20 of Set 5 | cabo san lucas
# Processing Record 21 of Set 5 | kendari
# Processing Record 22 of Set 5 | panzhihua
# Processing Record 23 of Set 5 | orgun
# City not found. Skipping...
# Processing Record 24 of Set 5 | portland
# Processing Record 25 of Set 5 | robertsport
# Processing Record 26 of Set 5 | sao filipe
# Processing Record 27 of Set 5 | khonuu
# City not found. Skipping...
# Processing Record 28 of Set 5 | sume
# Processing Record 29 of Set 5 | vestmannaeyjar
# Processing Record 30 of Set 5 | manokwari
# Processing Record 31 of Set 5 | tomatlan
# Processing Record 32 of Set 5 | quixada
# Processing Record 33 of Set 5 | rocky mountain house
# Processing Record 34 of Set 5 | souillac
# Processing Record 35 of Set 5 | sola
# Processing Record 36 of Set 5 | youkounkoun
# Processing Record 37 of Set 5 | douglas
# Processing Record 38 of Set 5 | cumaribo
# City not found. Skipping...
# Processing Record 39 of Set 5 | emerald
# Processing Record 40 of Set 5 | kalomo
# City not found. Skipping...
# Processing Record 41 of Set 5 | praia da vitoria
# Processing Record 42 of Set 5 | naryan-mar
# Processing Record 43 of Set 5 | palmer
# Processing Record 44 of Set 5 | khorol
# Processing Record 45 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 46 of Set 5 | hovd
# Processing Record 47 of Set 5 | nampula
# Processing Record 48 of Set 5 | torbay
# Processing Record 49 of Set 5 | quatre cocos
# Processing Record 50 of Set 5 | lewistown
# Processing Record 1 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 2 of Set 6 | litoral del san juan
# City not found. Skipping...
# Processing Record 3 of Set 6 | pangnirtung
# Processing Record 4 of Set 6 | rudbar
# Processing Record 5 of Set 6 | krasnoselkup
# Processing Record 6 of Set 6 | khorixas
# Processing Record 7 of Set 6 | ledyard
# Processing Record 8 of Set 6 | mosquera
# Processing Record 9 of Set 6 | omboue
# Processing Record 10 of Set 6 | axim
# Processing Record 11 of Set 6 | north bend
# Processing Record 12 of Set 6 | ugoofaaru
# Processing Record 13 of Set 6 | manyana
# Processing Record 14 of Set 6 | meulaboh
# Processing Record 15 of Set 6 | hobyo
# Processing Record 16 of Set 6 | bosaso
# Processing Record 17 of Set 6 | rio grande
# Processing Record 18 of Set 6 | galesong
# Processing Record 19 of Set 6 | matay
# Processing Record 20 of Set 6 | east london
# Processing Record 21 of Set 6 | kabare
# Processing Record 22 of Set 6 | salalah
# Processing Record 23 of Set 6 | atar
# Processing Record 24 of Set 6 | sisimiut
# Processing Record 25 of Set 6 | bagh
# Processing Record 26 of Set 6 | lagoa
# Processing Record 27 of Set 6 | flinders
# Processing Record 28 of Set 6 | puerto colombia
# Processing Record 29 of Set 6 | qaqortoq
# Processing Record 30 of Set 6 | baghdad
# Processing Record 31 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 32 of Set 6 | sioux lookout
# Processing Record 33 of Set 6 | samarai
# Processing Record 34 of Set 6 | ngukurr
# City not found. Skipping...
# Processing Record 35 of Set 6 | upernavik
# Processing Record 36 of Set 6 | lerwick
# Processing Record 37 of Set 6 | te karaka
# Processing Record 38 of Set 6 | saint george
# Processing Record 39 of Set 6 | constitucion
# Processing Record 40 of Set 6 | yuryev-polskiy
# Processing Record 41 of Set 6 | victoria
# Processing Record 42 of Set 6 | luena
# Processing Record 43 of Set 6 | dikson
# Processing Record 44 of Set 6 | leh
# Processing Record 45 of Set 6 | sibu
# Processing Record 46 of Set 6 | namatanai
# Processing Record 47 of Set 6 | dudesti
# Processing Record 48 of Set 6 | puerto del rosario
# Processing Record 49 of Set 6 | ulladulla
# Processing Record 50 of Set 6 | farmington
# Processing Record 1 of Set 7 | khuzhir
# Processing Record 2 of Set 7 | niksar
# Processing Record 3 of Set 7 | tagusao
# Processing Record 4 of Set 7 | port shepstone
# Processing Record 5 of Set 7 | santiago del estero
# Processing Record 6 of Set 7 | nsanje
# Processing Record 7 of Set 7 | thompson
# Processing Record 8 of Set 7 | itarema
# Processing Record 9 of Set 7 | touros
# Processing Record 10 of Set 7 | amuntai
# Processing Record 11 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 12 of Set 7 | ruatoria
# City not found. Skipping...
# Processing Record 13 of Set 7 | bethel
# Processing Record 14 of Set 7 | macas
# Processing Record 15 of Set 7 | bairnsdale
# Processing Record 16 of Set 7 | coahuayana
# Processing Record 17 of Set 7 | port lincoln
# Processing Record 18 of Set 7 | yining
# Processing Record 19 of Set 7 | chuy
# Processing Record 20 of Set 7 | saint john
# Processing Record 21 of Set 7 | sembe
# Processing Record 22 of Set 7 | dutlwe
# Processing Record 23 of Set 7 | ekhabi
# Processing Record 24 of Set 7 | richards bay
# Processing Record 25 of Set 7 | aklavik
# Processing Record 26 of Set 7 | dagana
# Processing Record 27 of Set 7 | faanui
# Processing Record 28 of Set 7 | tasiilaq
# Processing Record 29 of Set 7 | cherskiy
# Processing Record 30 of Set 7 | tiksi
# Processing Record 31 of Set 7 | aksarka
# Processing Record 32 of Set 7 | ayni
# Processing Record 33 of Set 7 | pisco
# Processing Record 34 of Set 7 | christchurch
# Processing Record 35 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 36 of Set 7 | svetlaya
# Processing Record 37 of Set 7 | dreux
# Processing Record 38 of Set 7 | mitu
# Processing Record 39 of Set 7 | bayan
# Processing Record 40 of Set 7 | jiddah
# City not found. Skipping...
# Processing Record 41 of Set 7 | carballo
# Processing Record 42 of Set 7 | muzhi
# Processing Record 43 of Set 7 | provideniya
# Processing Record 44 of Set 7 | vaghodia
# Processing Record 45 of Set 7 | bereda
# Processing Record 46 of Set 7 | takoradi
# Processing Record 47 of Set 7 | kieta
# Processing Record 48 of Set 7 | maniitsoq
# Processing Record 49 of Set 7 | karasburg
# Processing Record 50 of Set 7 | college
# Processing Record 1 of Set 8 | gat
# Processing Record 2 of Set 8 | buraydah
# Processing Record 3 of Set 8 | lebu
# Processing Record 4 of Set 8 | shaping
# Processing Record 5 of Set 8 | khandbari
# Processing Record 6 of Set 8 | kerouane
# Processing Record 7 of Set 8 | sur
# Processing Record 8 of Set 8 | minot
# Processing Record 9 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 10 of Set 8 | noyabrsk
# Processing Record 11 of Set 8 | vila velha
# Processing Record 12 of Set 8 | tezu
# Processing Record 13 of Set 8 | sandwick
# Processing Record 14 of Set 8 | okhotsk
# Processing Record 15 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 16 of Set 8 | atasu
# Processing Record 17 of Set 8 | matamoros
# Processing Record 18 of Set 8 | mount isa
# Processing Record 19 of Set 8 | wiarton
# Processing Record 20 of Set 8 | airai
# Processing Record 21 of Set 8 | poya
# Processing Record 22 of Set 8 | gravdal
# Processing Record 23 of Set 8 | pasni
# Processing Record 24 of Set 8 | isangel
# Processing Record 25 of Set 8 | greenville
# Processing Record 26 of Set 8 | alyangula
# Processing Record 27 of Set 8 | mount darwin
# Processing Record 28 of Set 8 | kurumkan
# Processing Record 29 of Set 8 | todos santos
# Processing Record 30 of Set 8 | lander
# Processing Record 31 of Set 8 | shingu
# Processing Record 32 of Set 8 | makakilo city
# Processing Record 33 of Set 8 | poissy
# Processing Record 34 of Set 8 | antofagasta
# Processing Record 35 of Set 8 | pasighat
# Processing Record 36 of Set 8 | warmbad
# Processing Record 37 of Set 8 | morgan city
# Processing Record 38 of Set 8 | ukiah
# Processing Record 39 of Set 8 | viedma
# Processing Record 40 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 41 of Set 8 | esperance
# Processing Record 42 of Set 8 | tymovskoye
# Processing Record 43 of Set 8 | san jose
# Processing Record 44 of Set 8 | agadez
# Processing Record 45 of Set 8 | mitsamiouli
# Processing Record 46 of Set 8 | nome
# Processing Record 47 of Set 8 | zyryanka
# Processing Record 48 of Set 8 | san patricio
# Processing Record 49 of Set 8 | berlevag
# Processing Record 50 of Set 8 | sao joao da barra
# Processing Record 1 of Set 9 | sebastian
# Processing Record 2 of Set 9 | qandala
# Processing Record 3 of Set 9 | dundee
# Processing Record 4 of Set 9 | nagtipunan
# Processing Record 5 of Set 9 | wahran
# City not found. Skipping...
# Processing Record 6 of Set 9 | ilhabela
# Processing Record 7 of Set 9 | comodoro rivadavia
# Processing Record 8 of Set 9 | ondorhaan
# City not found. Skipping...
# Processing Record 9 of Set 9 | shkotovo-22
# City not found. Skipping...
# Processing Record 10 of Set 9 | bulgan
# Processing Record 11 of Set 9 | burica
# City not found. Skipping...
# Processing Record 12 of Set 9 | faya
# Processing Record 13 of Set 9 | lebedyn
# Processing Record 14 of Set 9 | miandrivazo
# Processing Record 15 of Set 9 | denpasar
# Processing Record 16 of Set 9 | maningrida
# Processing Record 17 of Set 9 | borovskoy
# Processing Record 18 of Set 9 | zumpahuacan
# Processing Record 19 of Set 9 | korla
# Processing Record 20 of Set 9 | kapoeta
# Processing Record 21 of Set 9 | moranbah
# Processing Record 22 of Set 9 | tura
# Processing Record 23 of Set 9 | jumla
# Processing Record 24 of Set 9 | cumana
# Processing Record 25 of Set 9 | taoudenni
# Processing Record 26 of Set 9 | angren
# Processing Record 27 of Set 9 | maumere
# Processing Record 28 of Set 9 | morris
# Processing Record 29 of Set 9 | kaduqli
# Processing Record 30 of Set 9 | sept-iles
# Processing Record 31 of Set 9 | nikolsk
# Processing Record 32 of Set 9 | kazachinskoye
# Processing Record 33 of Set 9 | homer
# Processing Record 34 of Set 9 | tchollire
# Processing Record 35 of Set 9 | mutsamudu
# City not found. Skipping...
# Processing Record 36 of Set 9 | vetlanda
# Processing Record 37 of Set 9 | verkhnyaya inta
# Processing Record 38 of Set 9 | lasa
# Processing Record 39 of Set 9 | domna
# Processing Record 40 of Set 9 | nemuro
# Processing Record 41 of Set 9 | moissac
# Processing Record 42 of Set 9 | broken hill
# Processing Record 43 of Set 9 | poum
# Processing Record 44 of Set 9 | waingapu
# Processing Record 45 of Set 9 | zachagansk
# City not found. Skipping...
# Processing Record 46 of Set 9 | baykit
# Processing Record 47 of Set 9 | raudeberg
# Processing Record 48 of Set 9 | vanimo
# Processing Record 49 of Set 9 | forestville
# Processing Record 50 of Set 9 | severo-kurilsk
# Processing Record 1 of Set 10 | varniai
# Processing Record 2 of Set 10 | kudahuvadhoo
# Processing Record 3 of Set 10 | mahanoro
# Processing Record 4 of Set 10 | skalistyy
# City not found. Skipping...
# Processing Record 5 of Set 10 | namibe
# Processing Record 6 of Set 10 | kajaani
# Processing Record 7 of Set 10 | hunza
# City not found. Skipping...
# Processing Record 8 of Set 10 | paucartambo
# City not found. Skipping...
# Processing Record 9 of Set 10 | port hardy
# Processing Record 10 of Set 10 | develi
# Processing Record 11 of Set 10 | bassano
# Processing Record 12 of Set 10 | bada
# Processing Record 13 of Set 10 | vissenbjerg
# Processing Record 14 of Set 10 | san juan de betulia
# Processing Record 15 of Set 10 | umba
# Processing Record 16 of Set 10 | tautira
# Processing Record 17 of Set 10 | vuktyl
# Processing Record 18 of Set 10 | santa cruz
# Processing Record 19 of Set 10 | omsukchan
# Processing Record 20 of Set 10 | porto velho
# Processing Record 21 of Set 10 | kalakamati
# Processing Record 22 of Set 10 | kamenka
# Processing Record 23 of Set 10 | laguna
# Processing Record 24 of Set 10 | fairbanks
# Processing Record 25 of Set 10 | jimma
# Processing Record 26 of Set 10 | lucapa
# Processing Record 27 of Set 10 | catumbela
# Processing Record 28 of Set 10 | curillo
# Processing Record 29 of Set 10 | olafsvik
# Processing Record 30 of Set 10 | karratha
# Processing Record 31 of Set 10 | swan river
# Processing Record 32 of Set 10 | belyy yar
# Processing Record 33 of Set 10 | ottumwa
# Processing Record 34 of Set 10 | pampa
# Processing Record 35 of Set 10 | mareeba
# Processing Record 36 of Set 10 | manzil salim
# Processing Record 37 of Set 10 | karanja
# Processing Record 38 of Set 10 | irbit
# Processing Record 39 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 40 of Set 10 | aripuana
# Processing Record 41 of Set 10 | honningsvag
# Processing Record 42 of Set 10 | kaoma
# Processing Record 43 of Set 10 | akdepe
# Processing Record 44 of Set 10 | saveh
# Processing Record 45 of Set 10 | sari
# Processing Record 46 of Set 10 | yar-sale
# Processing Record 47 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 48 of Set 10 | klisura
# Processing Record 49 of Set 10 | mikuni
# Processing Record 50 of Set 10 | yemelyanovo
# Processing Record 1 of Set 11 | codrington
# Processing Record 2 of Set 11 | bambous virieux
# Processing Record 3 of Set 11 | araouane
# Processing Record 4 of Set 11 | paamiut
# Processing Record 5 of Set 11 | mogadishu
# Processing Record 6 of Set 11 | plover
# Processing Record 7 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 8 of Set 11 | balkanabat
# Processing Record 9 of Set 11 | miracatu
# Processing Record 10 of Set 11 | norman wells
# Processing Record 11 of Set 11 | yarada
# Processing Record 12 of Set 11 | port macquarie
# Processing Record 13 of Set 11 | oneida
# Processing Record 14 of Set 11 | buriti dos lopes
# Processing Record 15 of Set 11 | partizanskoye
# Processing Record 16 of Set 11 | pauini
# Processing Record 17 of Set 11 | kenai
# Processing Record 18 of Set 11 | kiruna
# Processing Record 19 of Set 11 | lemesos
# City not found. Skipping...
# Processing Record 20 of Set 11 | vostok
# Processing Record 21 of Set 11 | taltal
# Processing Record 22 of Set 11 | banda aceh
# Processing Record 23 of Set 11 | santa cruz cabralia
# Processing Record 24 of Set 11 | conil
# Processing Record 25 of Set 11 | causapscal
# Processing Record 26 of Set 11 | oudtshoorn
# Processing Record 27 of Set 11 | metkovic
# Processing Record 28 of Set 11 | thessalon
# Processing Record 29 of Set 11 | asheboro
# Processing Record 30 of Set 11 | sirnak
# Processing Record 31 of Set 11 | the valley
# Processing Record 32 of Set 11 | mackay
# Processing Record 33 of Set 11 | victoria point
# Processing Record 34 of Set 11 | asau
# Processing Record 35 of Set 11 | oga
# Processing Record 36 of Set 11 | half moon bay
# Processing Record 37 of Set 11 | kamaishi
# Processing Record 38 of Set 11 | wau
# Processing Record 39 of Set 11 | yumen
# Processing Record 40 of Set 11 | komsomolskiy
# Processing Record 41 of Set 11 | tagbac
# Processing Record 42 of Set 11 | manggar
# Processing Record 43 of Set 11 | te anau
# Processing Record 44 of Set 11 | tambun
# Processing Record 45 of Set 11 | hobbs
# Processing Record 46 of Set 11 | avera
# Processing Record 47 of Set 11 | dioknisi
# Processing Record 48 of Set 11 | morlaix
# Processing Record 49 of Set 11 | amahai
# Processing Record 50 of Set 11 | montrose
# Processing Record 1 of Set 12 | svoboda nad upou
# Processing Record 2 of Set 12 | paita
# Processing Record 3 of Set 12 | bastia
# Processing Record 4 of Set 12 | petropavlivka
# Processing Record 5 of Set 12 | vila
# Processing Record 6 of Set 12 | smithers
# Processing Record 7 of Set 12 | staraya sunzha
# Processing Record 8 of Set 12 | coquimbo
# Processing Record 9 of Set 12 | teya
# Processing Record 10 of Set 12 | leningradskiy
# Processing Record 11 of Set 12 | maymanak
# City not found. Skipping...
# Processing Record 12 of Set 12 | togul
# Processing Record 13 of Set 12 | mecca
# Processing Record 14 of Set 12 | lata
# Processing Record 15 of Set 12 | aykhal
# Processing Record 16 of Set 12 | van buren
# Processing Record 17 of Set 12 | kawalu
# Processing Record 18 of Set 12 | tamiahua
# Processing Record 19 of Set 12 | cayenne
# Processing Record 20 of Set 12 | verin
# Processing Record 21 of Set 12 | san rafael
# Processing Record 22 of Set 12 | magdalena
# Processing Record 23 of Set 12 | kuala pilah
# Processing Record 24 of Set 12 | vagur
# Processing Record 25 of Set 12 | biankouma
# Processing Record 26 of Set 12 | westport
# Processing Record 27 of Set 12 | maceio
# Processing Record 28 of Set 12 | nouakchott
# Processing Record 29 of Set 12 | bandarbeyla
# Processing Record 30 of Set 12 | hambantota
# Processing Record 31 of Set 12 | vietri sul mare
# Processing Record 32 of Set 12 | basoko
# Processing Record 33 of Set 12 | dunedin
# Processing Record 34 of Set 12 | santa cruz de la palma
# Processing Record 35 of Set 12 | brigantine
# Processing Record 36 of Set 12 | suntar
# Processing Record 37 of Set 12 | dongsheng
# Processing Record 38 of Set 12 | bokspits
# City not found. Skipping...
# Processing Record 39 of Set 12 | kingsport
# Processing Record 40 of Set 12 | pulaski
# Processing Record 41 of Set 12 | ulety
# Processing Record 42 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 43 of Set 12 | moindou
# Processing Record 44 of Set 12 | tucupita
# Processing Record 45 of Set 12 | perevolotskiy
# Processing Record 46 of Set 12 | lompoc
# Processing Record 47 of Set 12 | imeni babushkina
# Processing Record 48 of Set 12 | boa vista
# Processing Record 49 of Set 12 | ostrovnoy
# Processing Record 50 of Set 12 | turukhansk
# Processing Record 1 of Set 13 | zheleznodorozhnyy
# Processing Record 2 of Set 13 | walvis bay
# Processing Record 3 of Set 13 | burns lake
# Processing Record 4 of Set 13 | whitehorse
# Processing Record 5 of Set 13 | dianopolis
# City not found. Skipping...
# Processing Record 6 of Set 13 | eyl
# Processing Record 7 of Set 13 | lamu
# Processing Record 8 of Set 13 | calama
# Processing Record 9 of Set 13 | barbar
# City not found. Skipping...
# Processing Record 10 of Set 13 | shelburne
# Processing Record 11 of Set 13 | mandan
# Processing Record 12 of Set 13 | steinbach
# Processing Record 13 of Set 13 | ndele
# Processing Record 14 of Set 13 | adwa
# Processing Record 15 of Set 13 | cao bang
# Processing Record 16 of Set 13 | beloha
# Processing Record 17 of Set 13 | tazovskiy
# Processing Record 18 of Set 13 | champerico
# Processing Record 19 of Set 13 | fillira
# City not found. Skipping...
# Processing Record 20 of Set 13 | morros
# Processing Record 21 of Set 13 | dingle
# Processing Record 22 of Set 13 | rio gallegos
# Processing Record 23 of Set 13 | santa maria
# Processing Record 24 of Set 13 | yefira
# City not found. Skipping...
# Processing Record 25 of Set 13 | san quintin
# Processing Record 26 of Set 13 | kjopsvik
# Processing Record 27 of Set 13 | ossora
# Processing Record 28 of Set 13 | sladkovo
# Processing Record 29 of Set 13 | gillette
# Processing Record 30 of Set 13 | marawi
# Processing Record 31 of Set 13 | mehamn
# Processing Record 32 of Set 13 | yulara
# Processing Record 33 of Set 13 | kjollefjord
# Processing Record 34 of Set 13 | bubaque
# Processing Record 35 of Set 13 | warri
# Processing Record 36 of Set 13 | huarmey
# Processing Record 37 of Set 13 | skjervoy
# Processing Record 38 of Set 13 | kyra
# Processing Record 39 of Set 13 | kalmunai
# Processing Record 40 of Set 13 | bourges
# Processing Record 41 of Set 13 | maine-soroa
# Processing Record 42 of Set 13 | mithimna
# City not found. Skipping...
# Processing Record 43 of Set 13 | virginia beach
# Processing Record 44 of Set 13 | yuncheng
# Processing Record 45 of Set 13 | adre
# Processing Record 46 of Set 13 | saint-georges
# Processing Record 47 of Set 13 | juneau
# Processing Record 48 of Set 13 | matane
# Processing Record 49 of Set 13 | arman
# Processing Record 50 of Set 13 | verkhnevilyuysk
# Processing Record 1 of Set 14 | mathbaria
# Processing Record 2 of Set 14 | el ejido
# Processing Record 3 of Set 14 | kenora
# Processing Record 4 of Set 14 | savantvadi
# Processing Record 5 of Set 14 | nizwa
# Processing Record 6 of Set 14 | tondano
# Processing Record 7 of Set 14 | clarence town
# Processing Record 8 of Set 14 | ipinda
# Processing Record 9 of Set 14 | wanaka
# Processing Record 10 of Set 14 | siavonga
# Processing Record 11 of Set 14 | naze
# Processing Record 12 of Set 14 | berdigestyakh
# Processing Record 13 of Set 14 | yusva
# City not found. Skipping...
# Processing Record 14 of Set 14 | gazanjyk
# Processing Record 15 of Set 14 | mayumba
# Processing Record 16 of Set 14 | hanko
# Processing Record 17 of Set 14 | inhambane
# Processing Record 18 of Set 14 | novoagansk
# Processing Record 19 of Set 14 | grants pass
# Processing Record 20 of Set 14 | curitibanos
# Processing Record 21 of Set 14 | gua musang
# Processing Record 22 of Set 14 | pedra azul
# Processing Record 23 of Set 14 | ulaangom
# Processing Record 24 of Set 14 | alta floresta
# Processing Record 25 of Set 14 | svetlyy
# Processing Record 26 of Set 14 | ariquemes
# Processing Record 27 of Set 14 | gouyave
# Processing Record 28 of Set 14 | curup
# Processing Record 29 of Set 14 | mezen
# Processing Record 30 of Set 14 | mamlyutka
# Processing Record 31 of Set 14 | paonta sahib
# Processing Record 32 of Set 14 | corrente
# Processing Record 33 of Set 14 | mendahara
# City not found. Skipping...
# Processing Record 34 of Set 14 | labrea
# Processing Record 35 of Set 14 | marsa matruh
# Processing Record 36 of Set 14 | abha
# Processing Record 37 of Set 14 | nipawin
# Processing Record 38 of Set 14 | opuwo
# Processing Record 39 of Set 14 | aguimes
# Processing Record 40 of Set 14 | tynda
# Processing Record 41 of Set 14 | kurtamysh
# Processing Record 42 of Set 14 | vama buzaului
# City not found. Skipping...
# Processing Record 43 of Set 14 | harper
# Processing Record 44 of Set 14 | uran
# Processing Record 45 of Set 14 | niort
# Processing Record 46 of Set 14 | roald
# Processing Record 47 of Set 14 | otavi
# Processing Record 48 of Set 14 | aswan
# Processing Record 49 of Set 14 | tongren
# Processing Record 50 of Set 14 | singaraja
# Processing Record 1 of Set 15 | gweta
# Processing Record 2 of Set 15 | sao gabriel da cachoeira
# Processing Record 3 of Set 15 | roseburg
# Processing Record 4 of Set 15 | najran
# Processing Record 5 of Set 15 | cotonou
# Processing Record 6 of Set 15 | tateyama
# Processing Record 7 of Set 15 | maneadero
# Processing Record 8 of Set 15 | grand island
# Processing Record 9 of Set 15 | wuda
# Processing Record 10 of Set 15 | masyaf
# Processing Record 11 of Set 15 | kristiansund
# Processing Record 12 of Set 15 | mocuba
# Processing Record 13 of Set 15 | lago da pedra
# Processing Record 14 of Set 15 | hualmay
# Processing Record 15 of Set 15 | creston
# Processing Record 16 of Set 15 | ocampo
# Processing Record 17 of Set 15 | hun
# Processing Record 18 of Set 15 | vardo
# Processing Record 19 of Set 15 | pascagoula
# Processing Record 20 of Set 15 | north battleford
# Processing Record 21 of Set 15 | kautokeino
# Processing Record 22 of Set 15 | urumqi
# Processing Record 23 of Set 15 | preobrazheniye
# Processing Record 24 of Set 15 | kavaratti
# Processing Record 25 of Set 15 | tabou
# Processing Record 26 of Set 15 | medea
# Processing Record 27 of Set 15 | gewane
# Processing Record 28 of Set 15 | bargal
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Tally the number of cities in the city_data array of dictionaries
len(city_data)
# Out:
# 670

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Butaritari      KI   3.0707  172.7902     80.96        77          86
# 1        Rikitea      PF -23.1203 -134.9692     76.82        80          76
# 2     Port Blair      IN  11.6667   92.7500     82.22        80         100
# 3          Binga      ZW -17.6203   27.3414     68.25        49           4
# 4       Hermanus      ZA -34.4187   19.2345     59.05        85          52
# 5    New Norfolk      AU -42.7826  147.0587     42.30        80          19
# 6     Bredasdorp      ZA -34.5322   20.0403     56.61        86          47
# 7  San Cristobal      VE   7.7669  -72.2250     78.98        37          90
# 8      Mahebourg      MU -20.4081   57.7000     75.25        68          20
# 9        Ushuaia      AR -54.8000  -68.3000     35.26        87          75
#
#    Wind Speed Current Description
# 0        8.21          light rain
# 1       24.61          light rain
# 2       10.80     overcast clouds
# 3        5.10           clear sky
# 4        4.36       broken clouds
# 5        2.64          few clouds
# 6        5.19    scattered clouds
# 7        9.53     overcast clouds
# 8       11.50          few clouds
# 9       10.36       broken clouds

# %%
# Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder
# Create the output file (CSV).
output_data_file = "../Weather_Database/WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
