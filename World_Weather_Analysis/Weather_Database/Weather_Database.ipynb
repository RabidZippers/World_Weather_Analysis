# %%
# Import dependencies
from citipy import citipy
import pandas as pd
import numpy as np
import json 
import requests
import timeit

from datetime import datetime
from config import weather_api_key

# %%
# Create a new set of 2,000 random latitudes and longitudes
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Unpack lat_lngs zip object into a list. This way, we only need to create a set of random latitudes and longitudes once. 
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)
print (coordinates)
# Out:
# [(-33.1740785050537, 154.89225445766886), (39.31466958281044, -0.7425187761685947), (-89.52346009774949, 89.93828086226694), (20.577221811748203, -5.15310651157651), (-82.36474517250787, 89.85081204673583), (-34.51279191422349, -57.36125700757603), (13.683655337161525, 73.34489020392562), (-46.80851526084634, -99.80507466556301), (-71.30569912709522, -75.37788194623388), (59.835273895627694, 63.0980856075505), (80.33148526603912, -17.036520072239483), (-73.56115709332093, -129.72909295408522), (-16.519851625993127, 102.14288467411001), (-64.58483846639368, -146.06201886316592), (-62.688579063765445, 70.06971048325113), (-86.51904197533243, 88.67238600949361), (-71.89508388729223, 115.21346837281084), (-83.99358305410267, 111.43024942509192), (-33.48911918523637, 57.03516288037301), (-77.83931604427248, 70.21956173299898), (-45.956233520208436, 167.39825649062863), (39.63405229473105, -69.65594543224606), (-27.748033761171484, -116.47642716820644), (64.37153557029279, -37.96104977151529), (-9.299602738523461, -150.10867133405523), (-32.22102194883605, -19.196498673768843), (54.1348359101284, -148.50964876784582), (64.82747875760762, -87.92038939066603), (16.398284299491195, -132.92115256631706), (-72.49919308194359, 82.65847184039325), (68.05851939189375, -70.10918994244447), (48.97716150350601, -155.7427666316525), (4.532672476766663, -57.29936641792948), (-57.4401575762401, -127.00681096966497), (35.206004660815225, -145.31866599988064), (65.03585732751972, 25.12286056561655), (41.157584863971465, -68.27244025550867), (-59.1143921483421, -67.29426543658192), (73.26665090356704, 2.228618540366341), (8.981519744807812, -125.14955396528029), (-56.62984737007831, -137.57156089503462), (27.898423396495957, -175.69621860276675), (-31.787644001335586, -50.0214867703194), (22.77043297529994, -117.51404416392667), (-49.91396254776952, -124.61097642356452), (30.481782216609517, 159.12547002268025), (-84.2838035156946, 104.30029736633884), (-51.858484757609816, -110.07985349063226), (-89.9800675011215, -42.876986927778006), (15.517805948292462, 6.624783078747072), (58.89521827713713, -3.9991372085491435), (-46.90536813214126, 48.81072831634566), (85.16596762933759, -145.0025875400099), (55.13278128423693, -158.70646719165381), (-57.776518112699186, 149.39303708674333), (27.61625378644186, 157.67195517310404), (-52.84145778810483, -40.78355185187527), (57.08581490805048, 140.98134781107206), (-77.16699162810784, -94.36019230921974), (41.96016332207981, -155.8387468501073), (46.673216046168704, 107.00020721576556), (-52.28216045390516, -1.0868647254048085), (72.82055237727269, -87.6416709276877), (-64.73495629587242, 118.36296021182386), (-34.345648080811536, 90.91131328008623), (-53.98743790709803, 125.12170651603788), (-56.23485245679387, -168.6659115406577), (13.432979671305404, -103.05183862009258), (-54.1280529723671, 88.73671626847795), (61.58349615335433, 90.63203897667961), (-48.76706349490687, 64.41014102680589), (43.00568811699506, 92.55028777096271), (-30.061527100733535, -168.86133871014715), (-2.200181183570507, -63.51543018259294), (-73.66702812940154, -50.886278117258485), (46.05073273736912, 122.70765061523247), (-2.744178301665201, -6.082374692929676), (1.4052847789743907, 97.77137209354515), (-88.53179763667694, -66.70483657586836), (-19.742282004452306, 163.326523860142), (81.56281775226262, 143.2095696686435), (38.15337321896703, -174.8207250498393), (-50.1666510822567, 111.93123460491881), (63.89006665542928, -146.02168388045376), (-58.84769980278117, 165.2226364891165), (86.93487089677086, 29.638856162804103), (-60.228353202337416, 13.525146401593531), (-79.27767436806103, -36.14118844141478), (-55.26977702807575, 47.33037310114375), (11.411629224750996, 24.853283421477528), (4.690262481025428, -104.7541224002992), (71.2602745281244, -105.75099055071531), (11.512288781338142, 138.7667086811279), (73.46292532259139, -49.1549796295528), (-12.760874085321916, 178.83207843485746), (-5.929800006767991, 71.15283168849294), ...

# %%
# Get the nearest city using the citipy module
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 702

# %%
# Perform an API call with the OpenWeatherMap
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Retrieve the following information from the API call:
# Latitude and longitude
# Maximum temperature
# Percent humidity
# Percent cloudiness
# Wind speed
# Weather description (for example, clouds, fog, light rain, clear sky)

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        description = city_weather['weather'][0]['description']
        
        # Convert the date to ISO
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information to the city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":description })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | port macquarie
# Processing Record 2 of Set 1 | bunol
# Processing Record 3 of Set 1 | albany
# Processing Record 4 of Set 1 | araouane
# Processing Record 5 of Set 1 | busselton
# Processing Record 6 of Set 1 | juan lacaze
# Processing Record 7 of Set 1 | bhatkal
# Processing Record 8 of Set 1 | castro
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 10 of Set 1 | gari
# Processing Record 11 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 12 of Set 1 | rikitea
# Processing Record 13 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 14 of Set 1 | mataura
# Processing Record 15 of Set 1 | saint-philippe
# Processing Record 16 of Set 1 | saint-joseph
# Processing Record 17 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 18 of Set 1 | tuatapere
# Processing Record 19 of Set 1 | nantucket
# Processing Record 20 of Set 1 | tasiilaq
# Processing Record 21 of Set 1 | faanui
# Processing Record 22 of Set 1 | jamestown
# Processing Record 23 of Set 1 | kodiak
# Processing Record 24 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 25 of Set 1 | san quintin
# Processing Record 26 of Set 1 | clyde river
# Processing Record 27 of Set 1 | skeldon
# Processing Record 28 of Set 1 | kahului
# Processing Record 29 of Set 1 | haukipudas
# Processing Record 30 of Set 1 | bud
# Processing Record 31 of Set 1 | cabo san lucas
# Processing Record 32 of Set 1 | kapaa
# Processing Record 33 of Set 1 | palmares do sul
# Processing Record 34 of Set 1 | guerrero negro
# Processing Record 35 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 36 of Set 1 | abalak
# Processing Record 37 of Set 1 | thurso
# Processing Record 38 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 39 of Set 1 | barrow
# Processing Record 40 of Set 1 | bethel
# Processing Record 41 of Set 1 | hobart
# Processing Record 42 of Set 1 | hasaki
# Processing Record 43 of Set 1 | mar del plata
# Processing Record 44 of Set 1 | ayan
# Processing Record 45 of Set 1 | punta arenas
# Processing Record 46 of Set 1 | mandalgovi
# Processing Record 47 of Set 1 | cape town
# Processing Record 48 of Set 1 | qaanaaq
# Processing Record 49 of Set 1 | geraldton
# Processing Record 50 of Set 1 | vaini
# Processing Record 1 of Set 2 | petatlan
# Processing Record 2 of Set 2 | teya
# Processing Record 3 of Set 2 | hami
# Processing Record 4 of Set 2 | barcelos
# Processing Record 5 of Set 2 | baicheng
# Processing Record 6 of Set 2 | tabou
# Processing Record 7 of Set 2 | sibolga
# Processing Record 8 of Set 2 | poum
# Processing Record 9 of Set 2 | chokurdakh
# Processing Record 10 of Set 2 | fairbanks
# Processing Record 11 of Set 2 | bluff
# Processing Record 12 of Set 2 | mehamn
# Processing Record 13 of Set 2 | hermanus
# Processing Record 14 of Set 2 | east london
# Processing Record 15 of Set 2 | birao
# Processing Record 16 of Set 2 | acapulco
# Processing Record 17 of Set 2 | yellowknife
# Processing Record 18 of Set 2 | airai
# Processing Record 19 of Set 2 | ilulissat
# Processing Record 20 of Set 2 | asau
# Processing Record 21 of Set 2 | hithadhoo
# Processing Record 22 of Set 2 | butaritari
# Processing Record 23 of Set 2 | kannauj
# Processing Record 24 of Set 2 | sukhobezvodnoye
# Processing Record 25 of Set 2 | kamaishi
# Processing Record 26 of Set 2 | ponta delgada
# Processing Record 27 of Set 2 | ambodifototra
# City not found. Skipping...
# Processing Record 28 of Set 2 | xinxiang
# Processing Record 29 of Set 2 | brae
# Processing Record 30 of Set 2 | bhadrachalam
# Processing Record 31 of Set 2 | bredasdorp
# Processing Record 32 of Set 2 | beyneu
# Processing Record 33 of Set 2 | hilo
# Processing Record 34 of Set 2 | mosquera
# Processing Record 35 of Set 2 | sur
# Processing Record 36 of Set 2 | batagay-alyta
# Processing Record 37 of Set 2 | khatanga
# Processing Record 38 of Set 2 | kokorevka
# Processing Record 39 of Set 2 | malwan
# City not found. Skipping...
# Processing Record 40 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 41 of Set 2 | pandan
# Processing Record 42 of Set 2 | luderitz
# Processing Record 43 of Set 2 | colac
# Processing Record 44 of Set 2 | khonuu
# City not found. Skipping...
# Processing Record 45 of Set 2 | alice springs
# Processing Record 46 of Set 2 | bambous virieux
# Processing Record 47 of Set 2 | lagoa
# Processing Record 48 of Set 2 | wattegama
# Processing Record 49 of Set 2 | termini imerese
# Processing Record 50 of Set 2 | mayahi
# Processing Record 1 of Set 3 | dikson
# Processing Record 2 of Set 3 | rabat
# Processing Record 3 of Set 3 | kharan
# Processing Record 4 of Set 3 | yulara
# Processing Record 5 of Set 3 | sao joao da barra
# Processing Record 6 of Set 3 | sorland
# Processing Record 7 of Set 3 | carnarvon
# Processing Record 8 of Set 3 | tefe
# Processing Record 9 of Set 3 | campo de criptana
# Processing Record 10 of Set 3 | narsaq
# Processing Record 11 of Set 3 | cherskiy
# Processing Record 12 of Set 3 | meulaboh
# Processing Record 13 of Set 3 | myre
# Processing Record 14 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 15 of Set 3 | marawi
# Processing Record 16 of Set 3 | komsomolskiy
# Processing Record 17 of Set 3 | souillac
# Processing Record 18 of Set 3 | nikel
# Processing Record 19 of Set 3 | georgetown
# Processing Record 20 of Set 3 | esperance
# Processing Record 21 of Set 3 | port elizabeth
# Processing Record 22 of Set 3 | broome
# Processing Record 23 of Set 3 | elbistan
# Processing Record 24 of Set 3 | rawson
# Processing Record 25 of Set 3 | litoral del san juan
# City not found. Skipping...
# Processing Record 26 of Set 3 | adrar
# Processing Record 27 of Set 3 | cidreira
# Processing Record 28 of Set 3 | general pico
# Processing Record 29 of Set 3 | dickinson
# Processing Record 30 of Set 3 | bathsheba
# Processing Record 31 of Set 3 | touros
# Processing Record 32 of Set 3 | tuktoyaktuk
# Processing Record 33 of Set 3 | tiksi
# Processing Record 34 of Set 3 | vestmanna
# Processing Record 35 of Set 3 | maunabo
# Processing Record 36 of Set 3 | atuona
# Processing Record 37 of Set 3 | los llanos de aridane
# Processing Record 38 of Set 3 | mansoa
# Processing Record 39 of Set 3 | grand gaube
# Processing Record 40 of Set 3 | laguna
# Processing Record 41 of Set 3 | ballina
# Processing Record 42 of Set 3 | vaitape
# Processing Record 43 of Set 3 | puerto penasco
# Processing Record 44 of Set 3 | saskylakh
# Processing Record 45 of Set 3 | batagay
# Processing Record 46 of Set 3 | norman wells
# Processing Record 47 of Set 3 | bucerias
# Processing Record 48 of Set 3 | ewa beach
# Processing Record 49 of Set 3 | cabo rojo
# Processing Record 50 of Set 3 | thompson
# Processing Record 1 of Set 4 | abbeville
# Processing Record 2 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 3 of Set 4 | khani
# Processing Record 4 of Set 4 | port alfred
# Processing Record 5 of Set 4 | torbay
# Processing Record 6 of Set 4 | plettenberg bay
# Processing Record 7 of Set 4 | leningradskiy
# Processing Record 8 of Set 4 | iroquois falls
# Processing Record 9 of Set 4 | salalah
# Processing Record 10 of Set 4 | burnie
# Processing Record 11 of Set 4 | minab
# Processing Record 12 of Set 4 | clarksburg
# Processing Record 13 of Set 4 | shingu
# Processing Record 14 of Set 4 | puerto ayora
# Processing Record 15 of Set 4 | hambantota
# Processing Record 16 of Set 4 | arraial do cabo
# Processing Record 17 of Set 4 | conde
# Processing Record 18 of Set 4 | agadez
# Processing Record 19 of Set 4 | saint george
# Processing Record 20 of Set 4 | nouakchott
# Processing Record 21 of Set 4 | maymyo
# Processing Record 22 of Set 4 | mount gambier
# Processing Record 23 of Set 4 | coquimbo
# Processing Record 24 of Set 4 | lompoc
# Processing Record 25 of Set 4 | provideniya
# Processing Record 26 of Set 4 | taltal
# Processing Record 27 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 28 of Set 4 | cockburn town
# Processing Record 29 of Set 4 | olafsvik
# Processing Record 30 of Set 4 | fort saint john
# City not found. Skipping...
# Processing Record 31 of Set 4 | kamenka
# Processing Record 32 of Set 4 | bobo dioulasso
# Processing Record 33 of Set 4 | ca mau
# Processing Record 34 of Set 4 | coracao de jesus
# Processing Record 35 of Set 4 | troitskoye
# Processing Record 36 of Set 4 | manokwari
# Processing Record 37 of Set 4 | kaitangata
# Processing Record 38 of Set 4 | opuwo
# Processing Record 39 of Set 4 | upernavik
# Processing Record 40 of Set 4 | pangnirtung
# Processing Record 41 of Set 4 | marmato
# Processing Record 42 of Set 4 | banda aceh
# Processing Record 43 of Set 4 | aden
# Processing Record 44 of Set 4 | ostrovnoy
# Processing Record 45 of Set 4 | salinopolis
# Processing Record 46 of Set 4 | aporawan
# City not found. Skipping...
# Processing Record 47 of Set 4 | vostok
# Processing Record 48 of Set 4 | kruisfontein
# Processing Record 49 of Set 4 | kobryn
# Processing Record 50 of Set 4 | savyntsi
# Processing Record 1 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 2 of Set 5 | naples
# Processing Record 3 of Set 5 | naze
# Processing Record 4 of Set 5 | matara
# Processing Record 5 of Set 5 | strezhevoy
# Processing Record 6 of Set 5 | half moon bay
# Processing Record 7 of Set 5 | biak
# Processing Record 8 of Set 5 | jiayuguan
# Processing Record 9 of Set 5 | nisia floresta
# Processing Record 10 of Set 5 | lebu
# Processing Record 11 of Set 5 | freeport
# Processing Record 12 of Set 5 | barre
# Processing Record 13 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 14 of Set 5 | floriano
# Processing Record 15 of Set 5 | bengkulu
# Processing Record 16 of Set 5 | kavieng
# Processing Record 17 of Set 5 | port hardy
# Processing Record 18 of Set 5 | yorosso
# Processing Record 19 of Set 5 | comodoro rivadavia
# Processing Record 20 of Set 5 | port lincoln
# Processing Record 21 of Set 5 | sabla
# Processing Record 22 of Set 5 | montrose
# Processing Record 23 of Set 5 | anchorage
# Processing Record 24 of Set 5 | avera
# Processing Record 25 of Set 5 | avarua
# Processing Record 26 of Set 5 | tura
# Processing Record 27 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 28 of Set 5 | tautira
# Processing Record 29 of Set 5 | hualmay
# Processing Record 30 of Set 5 | el cairo
# Processing Record 31 of Set 5 | qaqortoq
# Processing Record 32 of Set 5 | ust-omchug
# Processing Record 33 of Set 5 | volginskiy
# City not found. Skipping...
# Processing Record 34 of Set 5 | ribeira grande
# Processing Record 35 of Set 5 | tambopata
# Processing Record 36 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 37 of Set 5 | hobyo
# Processing Record 38 of Set 5 | san cristobal
# Processing Record 39 of Set 5 | zyryanka
# Processing Record 40 of Set 5 | pyshchug
# Processing Record 41 of Set 5 | monaragala
# Processing Record 42 of Set 5 | morondava
# Processing Record 43 of Set 5 | saint-pierre
# Processing Record 44 of Set 5 | dawlatabad
# Processing Record 45 of Set 5 | ambon
# Processing Record 46 of Set 5 | haines junction
# Processing Record 47 of Set 5 | constitucion
# Processing Record 48 of Set 5 | lavrentiya
# Processing Record 49 of Set 5 | marsh harbour
# Processing Record 50 of Set 5 | nikolskoye
# Processing Record 1 of Set 6 | cabanas
# Processing Record 2 of Set 6 | nanortalik
# Processing Record 3 of Set 6 | nouadhibou
# Processing Record 4 of Set 6 | grand centre
# City not found. Skipping...
# Processing Record 5 of Set 6 | pomabamba
# Processing Record 6 of Set 6 | moradabad
# Processing Record 7 of Set 6 | kegalla
# City not found. Skipping...
# Processing Record 8 of Set 6 | turan
# Processing Record 9 of Set 6 | sembakung
# Processing Record 10 of Set 6 | huarmey
# Processing Record 11 of Set 6 | tornio
# Processing Record 12 of Set 6 | ponta do sol
# Processing Record 13 of Set 6 | batemans bay
# Processing Record 14 of Set 6 | cadillac
# Processing Record 15 of Set 6 | sambava
# Processing Record 16 of Set 6 | baruun-urt
# Processing Record 17 of Set 6 | kargopol
# Processing Record 18 of Set 6 | erenhot
# Processing Record 19 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 20 of Set 6 | skovorodino
# Processing Record 21 of Set 6 | wanaka
# Processing Record 22 of Set 6 | samarai
# Processing Record 23 of Set 6 | alofi
# Processing Record 24 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 25 of Set 6 | kapoeta
# Processing Record 26 of Set 6 | ilo
# Processing Record 27 of Set 6 | temaraia
# City not found. Skipping...
# Processing Record 28 of Set 6 | vao
# Processing Record 29 of Set 6 | kainantu
# Processing Record 30 of Set 6 | maloy
# Processing Record 31 of Set 6 | hervey bay
# Processing Record 32 of Set 6 | narrabri
# Processing Record 33 of Set 6 | ruatoria
# City not found. Skipping...
# Processing Record 34 of Set 6 | lata
# Processing Record 35 of Set 6 | the pas
# Processing Record 36 of Set 6 | monrovia
# Processing Record 37 of Set 6 | palmer
# Processing Record 38 of Set 6 | oranjemund
# Processing Record 39 of Set 6 | dunedin
# Processing Record 40 of Set 6 | nemuro
# Processing Record 41 of Set 6 | agirish
# Processing Record 42 of Set 6 | meyungs
# City not found. Skipping...
# Processing Record 43 of Set 6 | bandarbeyla
# Processing Record 44 of Set 6 | langerwehe
# Processing Record 45 of Set 6 | sobolevo
# Processing Record 46 of Set 6 | mahadday weyne
# City not found. Skipping...
# Processing Record 47 of Set 6 | aklavik
# Processing Record 48 of Set 6 | ancud
# Processing Record 49 of Set 6 | pevek
# Processing Record 50 of Set 6 | chihuahua
# Processing Record 1 of Set 7 | keti bandar
# Processing Record 2 of Set 7 | san patricio
# Processing Record 3 of Set 7 | afua
# Processing Record 4 of Set 7 | gat
# Processing Record 5 of Set 7 | carbonear
# Processing Record 6 of Set 7 | kuching
# Processing Record 7 of Set 7 | cowra
# Processing Record 8 of Set 7 | fairlie
# Processing Record 9 of Set 7 | moree
# Processing Record 10 of Set 7 | ullapool
# Processing Record 11 of Set 7 | new norfolk
# Processing Record 12 of Set 7 | esmeraldas
# Processing Record 13 of Set 7 | clarence town
# Processing Record 14 of Set 7 | englewood
# Processing Record 15 of Set 7 | hermiston
# Processing Record 16 of Set 7 | atar
# Processing Record 17 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 18 of Set 7 | ust-nera
# Processing Record 19 of Set 7 | hunucma
# Processing Record 20 of Set 7 | gamba
# Processing Record 21 of Set 7 | uyemskiy
# Processing Record 22 of Set 7 | sinnamary
# Processing Record 23 of Set 7 | praia da vitoria
# Processing Record 24 of Set 7 | ybycui
# Processing Record 25 of Set 7 | shache
# Processing Record 26 of Set 7 | lorengau
# Processing Record 27 of Set 7 | xam nua
# Processing Record 28 of Set 7 | concordia
# Processing Record 29 of Set 7 | worland
# Processing Record 30 of Set 7 | stantsiya gorchakovo
# City not found. Skipping...
# Processing Record 31 of Set 7 | port hedland
# Processing Record 32 of Set 7 | el faiyum
# City not found. Skipping...
# Processing Record 33 of Set 7 | hooglede
# Processing Record 34 of Set 7 | asosa
# Processing Record 35 of Set 7 | gizo
# Processing Record 36 of Set 7 | margate
# Processing Record 37 of Set 7 | champasak
# Processing Record 38 of Set 7 | longyearbyen
# Processing Record 39 of Set 7 | inderborskiy
# City not found. Skipping...
# Processing Record 40 of Set 7 | barcelona
# Processing Record 41 of Set 7 | kyle of lochalsh
# City not found. Skipping...
# Processing Record 42 of Set 7 | west wendover
# Processing Record 43 of Set 7 | port augusta
# Processing Record 44 of Set 7 | rybnoye
# Processing Record 45 of Set 7 | shimoda
# Processing Record 46 of Set 7 | tual
# Processing Record 47 of Set 7 | linjiang
# Processing Record 48 of Set 7 | mouzakion
# City not found. Skipping...
# Processing Record 49 of Set 7 | manoel urbano
# Processing Record 50 of Set 7 | bitung
# Processing Record 1 of Set 8 | iwaki
# Processing Record 2 of Set 8 | la ronge
# Processing Record 3 of Set 8 | vacha
# Processing Record 4 of Set 8 | ilhabela
# Processing Record 5 of Set 8 | de-kastri
# Processing Record 6 of Set 8 | along
# Processing Record 7 of Set 8 | namatanai
# Processing Record 8 of Set 8 | evensk
# Processing Record 9 of Set 8 | balabac
# Processing Record 10 of Set 8 | yeniseysk
# Processing Record 11 of Set 8 | menongue
# Processing Record 12 of Set 8 | xining
# Processing Record 13 of Set 8 | antalya
# Processing Record 14 of Set 8 | pisco
# Processing Record 15 of Set 8 | bartlesville
# Processing Record 16 of Set 8 | dakoro
# Processing Record 17 of Set 8 | aksarka
# Processing Record 18 of Set 8 | mayo
# Processing Record 19 of Set 8 | guajara-mirim
# City not found. Skipping...
# Processing Record 20 of Set 8 | valparaiso
# Processing Record 21 of Set 8 | timra
# Processing Record 22 of Set 8 | quelimane
# Processing Record 23 of Set 8 | talcher
# Processing Record 24 of Set 8 | aykhal
# Processing Record 25 of Set 8 | chuy
# Processing Record 26 of Set 8 | longlac
# City not found. Skipping...
# Processing Record 27 of Set 8 | port-gentil
# Processing Record 28 of Set 8 | tazovskiy
# Processing Record 29 of Set 8 | hastings
# Processing Record 30 of Set 8 | vardo
# Processing Record 31 of Set 8 | mahebourg
# Processing Record 32 of Set 8 | lamas
# Processing Record 33 of Set 8 | mecca
# Processing Record 34 of Set 8 | mamallapuram
# Processing Record 35 of Set 8 | abu kamal
# Processing Record 36 of Set 8 | joshimath
# Processing Record 37 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 38 of Set 8 | payakumbuh
# Processing Record 39 of Set 8 | palu
# Processing Record 40 of Set 8 | monastyrshchina
# Processing Record 41 of Set 8 | le portel
# Processing Record 42 of Set 8 | vega de alatorre
# Processing Record 43 of Set 8 | mildura
# Processing Record 44 of Set 8 | portland
# Processing Record 45 of Set 8 | benjamin constant
# Processing Record 46 of Set 8 | vanimo
# Processing Record 47 of Set 8 | vestmannaeyjar
# Processing Record 48 of Set 8 | khasan
# Processing Record 49 of Set 8 | taranagar
# Processing Record 50 of Set 8 | hohhot
# Processing Record 1 of Set 9 | egvekinot
# Processing Record 2 of Set 9 | caraballeda
# Processing Record 3 of Set 9 | martapura
# Processing Record 4 of Set 9 | whyalla
# Processing Record 5 of Set 9 | padang
# Processing Record 6 of Set 9 | nabire
# Processing Record 7 of Set 9 | feldkirchen an der donau
# Processing Record 8 of Set 9 | beringovskiy
# Processing Record 9 of Set 9 | thanatpin
# Processing Record 10 of Set 9 | te anau
# Processing Record 11 of Set 9 | byron bay
# Processing Record 12 of Set 9 | cicero dantas
# Processing Record 13 of Set 9 | winnemucca
# Processing Record 14 of Set 9 | iqaluit
# Processing Record 15 of Set 9 | mahibadhoo
# Processing Record 16 of Set 9 | srednekolymsk
# Processing Record 17 of Set 9 | muscle shoals
# Processing Record 18 of Set 9 | vila velha
# Processing Record 19 of Set 9 | mindelo
# Processing Record 20 of Set 9 | santa cruz
# Processing Record 21 of Set 9 | mandan
# Processing Record 22 of Set 9 | altay
# Processing Record 23 of Set 9 | olinda
# Processing Record 24 of Set 9 | kearney
# Processing Record 25 of Set 9 | kutum
# Processing Record 26 of Set 9 | kolokani
# Processing Record 27 of Set 9 | vila franca do campo
# Processing Record 28 of Set 9 | fengcheng
# Processing Record 29 of Set 9 | bowen
# Processing Record 30 of Set 9 | sibu
# Processing Record 31 of Set 9 | gap
# Processing Record 32 of Set 9 | sayyan
# Processing Record 33 of Set 9 | bahile
# Processing Record 34 of Set 9 | saint anthony
# Processing Record 35 of Set 9 | rio de janeiro
# Processing Record 36 of Set 9 | himora
# City not found. Skipping...
# Processing Record 37 of Set 9 | kadykchan
# City not found. Skipping...
# Processing Record 38 of Set 9 | doka
# Processing Record 39 of Set 9 | chase
# Processing Record 40 of Set 9 | aban
# Processing Record 41 of Set 9 | husavik
# Processing Record 42 of Set 9 | ahuimanu
# Processing Record 43 of Set 9 | faya
# Processing Record 44 of Set 9 | blagoyevo
# Processing Record 45 of Set 9 | sioux lookout
# Processing Record 46 of Set 9 | kurumkan
# Processing Record 47 of Set 9 | charters towers
# Processing Record 48 of Set 9 | orapa
# Processing Record 49 of Set 9 | najran
# Processing Record 50 of Set 9 | kavaratti
# Processing Record 1 of Set 10 | simpang
# Processing Record 2 of Set 10 | vitim
# Processing Record 3 of Set 10 | omsukchan
# Processing Record 4 of Set 10 | hofn
# Processing Record 5 of Set 10 | indramayu
# Processing Record 6 of Set 10 | guia de isora
# Processing Record 7 of Set 10 | gorom-gorom
# Processing Record 8 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 9 of Set 10 | kiama
# Processing Record 10 of Set 10 | lima
# Processing Record 11 of Set 10 | severo-kurilsk
# Processing Record 12 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 13 of Set 10 | castlecomer
# Processing Record 14 of Set 10 | tyrma
# Processing Record 15 of Set 10 | dolores
# Processing Record 16 of Set 10 | bagdarin
# Processing Record 17 of Set 10 | babanusah
# City not found. Skipping...
# Processing Record 18 of Set 10 | alibag
# Processing Record 19 of Set 10 | zaysan
# Processing Record 20 of Set 10 | hernani
# Processing Record 21 of Set 10 | guilin
# Processing Record 22 of Set 10 | aloleng
# Processing Record 23 of Set 10 | sitka
# Processing Record 24 of Set 10 | mustasaari
# Processing Record 25 of Set 10 | macroom
# Processing Record 26 of Set 10 | ostersund
# Processing Record 27 of Set 10 | parral
# Processing Record 28 of Set 10 | nyagan
# Processing Record 29 of Set 10 | bima
# Processing Record 30 of Set 10 | maseru
# Processing Record 31 of Set 10 | acari
# Processing Record 32 of Set 10 | aki
# Processing Record 33 of Set 10 | katangli
# Processing Record 34 of Set 10 | fortuna
# Processing Record 35 of Set 10 | nome
# Processing Record 36 of Set 10 | fort nelson
# Processing Record 37 of Set 10 | harper
# Processing Record 38 of Set 10 | buala
# Processing Record 39 of Set 10 | sala
# Processing Record 40 of Set 10 | talnakh
# Processing Record 41 of Set 10 | pathein
# Processing Record 42 of Set 10 | piacabucu
# Processing Record 43 of Set 10 | havelock
# Processing Record 44 of Set 10 | dudinka
# Processing Record 45 of Set 10 | klaksvik
# Processing Record 46 of Set 10 | itaituba
# Processing Record 47 of Set 10 | shirvan
# Processing Record 48 of Set 10 | kokopo
# Processing Record 49 of Set 10 | springdale
# Processing Record 50 of Set 10 | pacific grove
# Processing Record 1 of Set 11 | san andres
# Processing Record 2 of Set 11 | takab
# Processing Record 3 of Set 11 | spisska bela
# Processing Record 4 of Set 11 | oyugis
# Processing Record 5 of Set 11 | milingimbi
# City not found. Skipping...
# Processing Record 6 of Set 11 | kollumerland
# City not found. Skipping...
# Processing Record 7 of Set 11 | lagunas
# Processing Record 8 of Set 11 | buzmeyin
# Processing Record 9 of Set 11 | ikom
# Processing Record 10 of Set 11 | york
# Processing Record 11 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 12 of Set 11 | inta
# Processing Record 13 of Set 11 | kudahuvadhoo
# Processing Record 14 of Set 11 | falmouth
# Processing Record 15 of Set 11 | visby
# Processing Record 16 of Set 11 | sept-iles
# Processing Record 17 of Set 11 | leland
# Processing Record 18 of Set 11 | surt
# Processing Record 19 of Set 11 | rocha
# Processing Record 20 of Set 11 | oktyabrskiy
# Processing Record 21 of Set 11 | victoria
# Processing Record 22 of Set 11 | bilibino
# Processing Record 23 of Set 11 | tumpat
# Processing Record 24 of Set 11 | sidi ali
# Processing Record 25 of Set 11 | general roca
# Processing Record 26 of Set 11 | sao filipe
# Processing Record 27 of Set 11 | mahon
# Processing Record 28 of Set 11 | anadyr
# Processing Record 29 of Set 11 | funadhoo
# Processing Record 30 of Set 11 | luangwa
# Processing Record 31 of Set 11 | flinders
# Processing Record 32 of Set 11 | zadonsk
# Processing Record 33 of Set 11 | nhulunbuy
# Processing Record 34 of Set 11 | henties bay
# Processing Record 35 of Set 11 | gladstone
# Processing Record 36 of Set 11 | farah
# Processing Record 37 of Set 11 | nguru
# Processing Record 38 of Set 11 | loiza
# Processing Record 39 of Set 11 | hit
# Processing Record 40 of Set 11 | nelson bay
# Processing Record 41 of Set 11 | hede
# Processing Record 42 of Set 11 | inongo
# Processing Record 43 of Set 11 | tete
# Processing Record 44 of Set 11 | rabo de peixe
# Processing Record 45 of Set 11 | ksenyevka
# City not found. Skipping...
# Processing Record 46 of Set 11 | mongo
# Processing Record 47 of Set 11 | opunake
# Processing Record 48 of Set 11 | myanaung
# Processing Record 49 of Set 11 | marzuq
# Processing Record 50 of Set 11 | codrington
# Processing Record 1 of Set 12 | stoyba
# City not found. Skipping...
# Processing Record 2 of Set 12 | sawakin
# Processing Record 3 of Set 12 | kouango
# Processing Record 4 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 5 of Set 12 | ambilobe
# Processing Record 6 of Set 12 | tazmalt
# Processing Record 7 of Set 12 | dingle
# Processing Record 8 of Set 12 | wad rawah
# Processing Record 9 of Set 12 | kaeo
# Processing Record 10 of Set 12 | xuddur
# Processing Record 11 of Set 12 | diphu
# Processing Record 12 of Set 12 | gambela
# Processing Record 13 of Set 12 | nakhon thai
# Processing Record 14 of Set 12 | san pedro
# Processing Record 15 of Set 12 | luziania
# Processing Record 16 of Set 12 | mackenzie
# Processing Record 17 of Set 12 | badiraguato
# Processing Record 18 of Set 12 | yarmouth
# Processing Record 19 of Set 12 | westport
# Processing Record 20 of Set 12 | mnogovershinnyy
# Processing Record 21 of Set 12 | basco
# Processing Record 22 of Set 12 | zhuhai
# Processing Record 23 of Set 12 | mujiayingzi
# Processing Record 24 of Set 12 | tessalit
# Processing Record 25 of Set 12 | dalby
# Processing Record 26 of Set 12 | russell
# Processing Record 27 of Set 12 | sidney
# Processing Record 28 of Set 12 | saint-louis
# Processing Record 29 of Set 12 | turukhansk
# Processing Record 30 of Set 12 | grindavik
# Processing Record 31 of Set 12 | chikoy
# City not found. Skipping...
# Processing Record 32 of Set 12 | sangar
# Processing Record 33 of Set 12 | astana
# Processing Record 34 of Set 12 | haapu
# City not found. Skipping...
# Processing Record 35 of Set 12 | okhotsk
# Processing Record 36 of Set 12 | waddan
# Processing Record 37 of Set 12 | rivers
# Processing Record 38 of Set 12 | charagua
# Processing Record 39 of Set 12 | buchanan
# Processing Record 40 of Set 12 | fougamou
# Processing Record 41 of Set 12 | santa maria do suacui
# Processing Record 42 of Set 12 | pauini
# Processing Record 43 of Set 12 | acarau
# Processing Record 44 of Set 12 | whitehorse
# Processing Record 45 of Set 12 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 46 of Set 12 | jiroft
# City not found. Skipping...
# Processing Record 47 of Set 12 | svencioneliai
# Processing Record 48 of Set 12 | solnechnyy
# Processing Record 49 of Set 12 | mata
# Processing Record 50 of Set 12 | sharjah
# Processing Record 1 of Set 13 | launceston
# Processing Record 2 of Set 13 | alto araguaia
# Processing Record 3 of Set 13 | maceio
# Processing Record 4 of Set 13 | mackay
# Processing Record 5 of Set 13 | cayenne
# Processing Record 6 of Set 13 | matagami
# Processing Record 7 of Set 13 | pokhara
# Processing Record 8 of Set 13 | serenje
# Processing Record 9 of Set 13 | bambanglipuro
# Processing Record 10 of Set 13 | jacareacanga
# Processing Record 11 of Set 13 | cianjur
# Processing Record 12 of Set 13 | roma
# Processing Record 13 of Set 13 | roald
# Processing Record 14 of Set 13 | taksimo
# Processing Record 15 of Set 13 | watsa
# Processing Record 16 of Set 13 | khormuj
# City not found. Skipping...
# Processing Record 17 of Set 13 | aksu
# Processing Record 18 of Set 13 | kungurtug
# Processing Record 19 of Set 13 | melnikovo
# Processing Record 20 of Set 13 | san julian
# Processing Record 21 of Set 13 | shergarh
# Processing Record 22 of Set 13 | orel-izumrud
# Processing Record 23 of Set 13 | nuuk
# Processing Record 24 of Set 13 | archidona
# Processing Record 25 of Set 13 | bur gabo
# City not found. Skipping...
# Processing Record 26 of Set 13 | puro
# Processing Record 27 of Set 13 | pudem
# Processing Record 28 of Set 13 | johnstown
# Processing Record 29 of Set 13 | richards bay
# Processing Record 30 of Set 13 | prado
# Processing Record 31 of Set 13 | yining
# Processing Record 32 of Set 13 | san juan
# Processing Record 33 of Set 13 | mogapi
# Processing Record 34 of Set 13 | zhigalovo
# Processing Record 35 of Set 13 | kangaatsiaq
# Processing Record 36 of Set 13 | yakeshi
# Processing Record 37 of Set 13 | sheopur
# Processing Record 38 of Set 13 | saldanha
# Processing Record 39 of Set 13 | kargasok
# Processing Record 40 of Set 13 | hokitika
# Processing Record 41 of Set 13 | nizhniy kuranakh
# Processing Record 42 of Set 13 | bismarck
# Processing Record 43 of Set 13 | nuevo ideal
# Processing Record 44 of Set 13 | berlevag
# Processing Record 45 of Set 13 | isangel
# Processing Record 46 of Set 13 | wembley
# Processing Record 47 of Set 13 | bacungan
# Processing Record 48 of Set 13 | anqing
# Processing Record 49 of Set 13 | bonthe
# Processing Record 50 of Set 13 | lazaro cardenas
# Processing Record 1 of Set 14 | kirundo
# Processing Record 2 of Set 14 | chastoozerye
# City not found. Skipping...
# Processing Record 3 of Set 14 | port blair
# Processing Record 4 of Set 14 | alekseyevka
# Processing Record 5 of Set 14 | ixtapa
# Processing Record 6 of Set 14 | teguldet
# Processing Record 7 of Set 14 | topolobampo
# Processing Record 8 of Set 14 | kattivakkam
# Processing Record 9 of Set 14 | raahe
# Processing Record 10 of Set 14 | pimentel
# Processing Record 11 of Set 14 | male
# Processing Record 12 of Set 14 | phuket
# Processing Record 13 of Set 14 | ahaus
# Processing Record 14 of Set 14 | la primavera
# Processing Record 15 of Set 14 | udachnyy
# Processing Record 16 of Set 14 | pasni
# Processing Record 17 of Set 14 | krutinka
# Processing Record 18 of Set 14 | mporokoso
# Processing Record 19 of Set 14 | itarema
# Processing Record 20 of Set 14 | jefferson city
# Processing Record 21 of Set 14 | asuncion
# Processing Record 22 of Set 14 | cacequi
# Processing Record 23 of Set 14 | conakry
# Processing Record 24 of Set 14 | taoudenni
# Processing Record 25 of Set 14 | neyshabur
# Processing Record 26 of Set 14 | talara
# Processing Record 27 of Set 14 | manggar
# Processing Record 28 of Set 14 | bemidji
# Processing Record 29 of Set 14 | krasnoufimsk
# Processing Record 30 of Set 14 | mocuba
# Processing Record 31 of Set 14 | porto novo
# Processing Record 32 of Set 14 | suez
# Processing Record 33 of Set 14 | rio grande
# Processing Record 34 of Set 14 | diamantino
# Processing Record 35 of Set 14 | waw
# Processing Record 36 of Set 14 | barreiras
# Processing Record 37 of Set 14 | george
# Processing Record 38 of Set 14 | meadow lake
# Processing Record 39 of Set 14 | dicabisagan
# Processing Record 40 of Set 14 | novopokrovka
# Processing Record 41 of Set 14 | miyazu
# Processing Record 42 of Set 14 | guantanamo
# Processing Record 43 of Set 14 | taburi
# City not found. Skipping...
# Processing Record 44 of Set 14 | bonavista
# Processing Record 45 of Set 14 | lukovetskiy
# Processing Record 46 of Set 14 | solwezi
# Processing Record 47 of Set 14 | taga dzong
# City not found. Skipping...
# Processing Record 48 of Set 14 | la reforma
# Processing Record 49 of Set 14 | xinqing
# Processing Record 50 of Set 14 | doha
# Processing Record 1 of Set 15 | yilan
# Processing Record 2 of Set 15 | lasa
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Tally the number of cities in the city_data array of dictionaries
len(city_data)
# Out:
# 645

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Port Macquarie      AU -31.4333  152.9167     66.88        45           0
# 1           Bunol      ES  39.4167   -0.7833     64.90        50         100
# 2          Albany      US  42.6001  -73.9662     75.88        72         100
# 3        Araouane      ML  18.9048   -3.5265     94.69        14          56
# 4       Busselton      AU -33.6500  115.3333     58.51        67           1
# 5     Juan Lacaze      UY -34.4342  -57.4381     42.12        57          35
# 6         Bhatkal      IN  13.9667   74.5667     81.95        78          95
# 7          Castro      BR -24.7911  -50.0119     58.69        97         100
# 8         Ushuaia      AR -54.8000  -68.3000     42.46        81          75
# 9            Gari      RU  59.4307   62.3497     48.45        93         100
#
#    Wind Speed Current Description
# 0       14.58           clear sky
# 1        5.95     overcast clouds
# 2        4.65     overcast clouds
# 3       15.35       broken clouds
# 4        8.01           clear sky
# 5        9.55    scattered clouds
# 6        5.61     overcast clouds
# 7        4.74     overcast clouds
# 8       25.32          light rain
# 9        8.84     overcast clouds

# %%
# Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder
# Create the output file (CSV).
output_data_file = "../Weather_Database/WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
